# %%
from US_API_Test import *

# %%
events_data = fetch_events()
# Out:
# Fetched 194 events on page 0
# All pages have been fetched.

# %%
events_df = events_to_dataframe(events_data)
events_df
# Out:
#                                             Event Name        Date      Time  \
# 0                                    Championship Meet  2023-12-31  11:00:00
# 1                        Ultimate Fan Experience 12/31  2023-12-31  09:00:00
# 2                    Postgame On-field Pass - Patriots  2023-12-31  13:00:00
# 3                  Homestretch Club - Day at the Races  2023-12-31  13:00:00
# 4                Bud Light Friend Zone Pass - Panthers  2023-12-31  13:00:00
# ..                                                 ...         ...       ...
# 189                                       LAFC vs. TBD  2023-12-31  19:30:00
# 190                               The Magician's Study  2023-12-31  21:30:00
# 191                          BARNATO 2024 Sponsor Pass  2024-01-01  12:00:00
# 192                          BARNATO 2024 Sponsor Pass  2024-01-01  12:00:00
# 193  Ticket for you and a +1 to ALL 2024 shows at t...  2024-01-03  12:00:00
#
#                              Venue
# ...

# %%
print(events_df.describe())
print(events_df.info())
print('###')
print(events_df.tail(20))
# Out:
#             Event Name        Date      Time                           Venue
# count              194         194       194                             194
# unique             179           3        25                              86
# top     Spokane Chiefs  2023-12-31  18:00:00  GEHA Field @ Arrowhead Stadium
# freq                 3         191        40                              15
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 194 entries, 0 to 193
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Event Name  194 non-null    object
#  1   Date        194 non-null    object
#  2   Time        194 non-null    object
#  3   Venue       194 non-null    object
# dtypes: object(4)
# memory usage: 6.2+ KB
# None
# ###
#                                                                                 Event Name  \
# ...
